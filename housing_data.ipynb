# %%
import pandas
import os
from pathlib import Path

# %%
data = pandas.read_json("./data/2024-02-04.json")
data
# Out:
#     type         id                                         attributes  \
# 0    ads  105457640  {'date': '2024-02-04 16:19:23', 'modified_ts':...
# 1    ads  101194263  {'date': '2024-02-04 16:18:50', 'modified_ts':...
# 2    ads  104408145  {'date': '2024-02-04 16:18:21', 'modified_ts':...
# 3    ads  105475879  {'date': '2024-02-04 16:17:50', 'modified_ts':...
# 4    ads  105225597  {'date': '2024-02-04 16:17:33', 'modified_ts':...
# ..   ...        ...                                                ...
# 995  ads  104763331  {'date': '2024-02-04 18:29:31', 'modified_ts':...
# 996  ads  104763324  {'date': '2024-02-04 18:29:31', 'modified_ts':...
# 997  ads  105225283  {'date': '2024-02-04 18:29:30', 'modified_ts':...
# 998  ads  105531444  {'date': '2024-02-04 18:28:50', 'modified_ts':...
# 999  ads  104262283  {'date': '2024-02-04 18:28:41', 'modified_ts':...
#
#                                                  links
# 0    {'image_baseurl': 'https://img.rnudah.com/imag...
# 1    {'image_baseurl': 'https://img.rnudah.com/imag...
# 2    {'image_baseurl': 'https://img.rnudah.com/imag...
# 3    {'image_baseurl': 'https://img.rnudah.com/imag...
# 4    {'image_baseurl': 'https://img.rnudah.com/imag...
# ..                                                 ...
# 995  {'image_baseurl': 'https://img.rnudah.com/imag...
# 996  {'image_baseurl': 'https://img.rnudah.com/imag...
# 997  {'image_baseurl': 'https://img.rnudah.com/imag...
# 998  {'image_baseurl': 'https://img.rnudah.com/imag...
# 999  {'image_baseurl': 'https://img.rnudah.com/imag...
#
# [1000 rows x 4 columns]

# %%
data[data.duplicated(subset="id", keep="first")]
# Out:
#     type         id                                         attributes  \
# 800  ads  101817399  {'date': '2024-02-04 19:18:40', 'modified_ts':...
# 801  ads  101709396  {'date': '2024-02-04 19:18:40', 'modified_ts':...
# 802  ads  100780015  {'date': '2024-02-04 19:18:40', 'modified_ts':...
# 803  ads  100369189  {'date': '2024-02-04 19:18:40', 'modified_ts':...
# 804  ads  103401127  {'date': '2024-02-04 19:15:09', 'modified_ts':...
# ..   ...        ...                                                ...
# 995  ads  104763331  {'date': '2024-02-04 18:29:31', 'modified_ts':...
# 996  ads  104763324  {'date': '2024-02-04 18:29:31', 'modified_ts':...
# 997  ads  105225283  {'date': '2024-02-04 18:29:30', 'modified_ts':...
# 998  ads  105531444  {'date': '2024-02-04 18:28:50', 'modified_ts':...
# 999  ads  104262283  {'date': '2024-02-04 18:28:41', 'modified_ts':...
#
#                                                  links
# 800  {'image_baseurl': 'https://img.rnudah.com/imag...
# 801  {'image_baseurl': 'https://img.rnudah.com/imag...
# 802  {'image_baseurl': 'https://img.rnudah.com/imag...
# 803  {'image_baseurl': 'https://img.rnudah.com/imag...
# 804  {'image_baseurl': 'https://img.rnudah.com/imag...
# ..                                                 ...
# 995  {'image_baseurl': 'https://img.rnudah.com/imag...
# 996  {'image_baseurl': 'https://img.rnudah.com/imag...
# 997  {'image_baseurl': 'https://img.rnudah.com/imag...
# 998  {'image_baseurl': 'https://img.rnudah.com/imag...
# 999  {'image_baseurl': 'https://img.rnudah.com/imag...
#
# [200 rows x 4 columns]
